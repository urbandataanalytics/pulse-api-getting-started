# %%
# %load_ext autoreload
# %autoreload 2
    
import requests
from utils.settings import env

session = requests.Session()
session.headers = {
    "Authorization": env.API_KEY
    #'x-consumer-id': env.CONSUMER_ID,
    #'x-consumer-secret': env.CONSUMER_SECRET,
}
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from utils.comparables import Search
import pandas as pd

url = f"{env.PROXY}/api/integration/v2/valuation/composed"

params = dict(
    reference='0990305VK4709B0010IS'
)

response = session.get(url, params=params)

res = response.json()

m = None

if comparables:= res['valuation']['ECO']['comparables']:

    df = pd.DataFrame(comparables)

    lat = res['valuation']['asset']['lat']
    lon = res['valuation']['asset']['lon']
    
    s = Search(df=df, location=[lat, lon])

    distance = df.distance.max() * 1.001
    
    m = s.map(distance=distance)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ffecc00e1ddf803089792079f65aae4e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ffecc00e1ddf803089792079f65aae4e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ffecc00e1ddf803089792079f65aae4e = L.map(
#                 &quot;map_ffecc00e1ddf803089792079f65aae4e&quot;,
#                 {
#                     center: [40.45852734, -3.6978893350000006],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_131866f038dd9efae91fcb4cb4aedca6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_131866f038dd9efae91fcb4cb4aedca6.addTo(map_ffecc00e1ddf803089792079f65aae4e);
#
#
#             var marker_b949832fc97750168f43113238fd10a8 = L.marker(
#                 [40.4586644, -3.6979929],
#                 {&quot;lazy&quot;: true}
#             ).addTo(map_ffecc00e1ddf803089792079f65aae4e);
#
#
#         var popup_2649ad72ef6aa3ce1fdf1a7a00a68243 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e9c1196a8636083f7f384f95c32a4f87 = $(`&lt;div id=&quot;html_e9c1196a8636083f7f384f95c32a4f87&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;html&gt;         &lt;head&gt;             &lt;style&gt;                 .grid-container {                     display: grid;                     grid-template-columns: repeat(3, 1fr);                     gap: 10px;                 }                 .grid-item {                     width: 100px;                 }             &lt;/style&gt;         &lt;/head&gt;         &lt;body&gt;             &lt;p style=&quot;font-size:20px&quot; &gt;None&lt;/p&gt;             &lt;a target=_blank style=&quot;font-size:15px&quot; href=None&gt;listing url&lt;/a&gt;             &lt;div class=&quot;grid-container&quot;&gt;                              &lt;/div&gt;         &lt;/body&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_2649ad72ef6aa3ce1fdf1a7a00a68243.setContent(html_e9c1196a8636083f7f384f95c32a4f87);
#
#
#
#         marker_b949832fc97750168f43113238fd10a8.bindPopup(popup_2649ad72ef6aa3ce1fdf1a7a00a68243)
#         ;
#
#
#
#
#             var marker_cc324a1d44f3c37a8e641cd760a31b5d = L.marker(
#                 [40.45876, -3.6974177],
#                 {&quot;lazy&quot;: true}
#             ).addTo(map_ffecc00e1ddf803089792079f65aae4e);
#
#
#         var popup_c0a02aa2b601ff3b73fb1e19191d1ce1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6a0cc31bc2ba9874927ae6f336ef2f99 = $(`&lt;div id=&quot;html_6a0cc31bc2ba9874927ae6f336ef2f99&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;html&gt;         &lt;head&gt;             &lt;style&gt;                 .grid-container {                     display: grid;                     grid-template-columns: repeat(3, 1fr);                     gap: 10px;                 }                 .grid-item {                     width: 100px;                 }             &lt;/style&gt;         &lt;/head&gt;         &lt;body&gt;             &lt;p style=&quot;font-size:20px&quot; &gt;None&lt;/p&gt;             &lt;a target=_blank style=&quot;font-size:15px&quot; href=None&gt;listing url&lt;/a&gt;             &lt;div class=&quot;grid-container&quot;&gt;                              &lt;/div&gt;         &lt;/body&gt;     &lt;/html&gt;     &lt;/div&gt;`)[0];
#                 popup_c0a02aa2b601ff3b73fb1e19191d1ce1.setContent(html_6a0cc31bc2ba9874927ae6f336ef2f99);
#
#
#
#         marker_cc324a1d44f3c37a8e641cd760a31b5d.bindPopup(popup_c0a02aa2b601ff3b73fb1e19191d1ce1)
#         ;
#
#
#
#
#             var marker_72ad0ad834cbefe7417ac141e3655fb3 = L.marker(
#                 [40.4588678, -3.6977211],
#                 {&quot;lazy&quot;: true}
#             ).addTo(map_ffecc00e1ddf803089792079f65aae4e);
#
#
#         var popup_21e1c7c6425a7ffb090db252afda1406 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8470aaf831211de0ee3e103233f10f17 = $(`&lt;div id=&quot;html_8470aaf831211de0ee3e103233f10f17&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;html&gt;         &lt;head&gt;             &lt;style&gt;                 .grid-container {                     display: grid;                     grid-template-columns: repeat(3, 1fr);                     gap: 10px;                 }                 .grid-item {                     width: 100px;                 }             &lt;/style&gt;         &lt;/head&gt;         &lt;body&gt;             &lt;p style=&quot;font-size:20px&quot; &gt;None&lt;/p&gt;             &lt;a target=_blank style=&quot;font-size:15px&quot; href=None&gt;listing url&lt;/a&gt;             &lt;div class=&quot;gr
