# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !pip install folium pandas python-dotenv

# %% [markdown]
# ## Searching for comparables
#
# #### /api/integration/v2/comparables/search/advanced

# %%
from utils import Search

search = Search().request(
    address='Av de Brasil 4, madrid',
    typology_type_id=1,
    property_type_id=4,
    is_active=0,
    sort_by='distance',
    ascending=1,
)

search.map()
# Out:
# Total: 445 - Page: 1/15
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a2df5fde8f3e04d24ffe480b47da28f4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a2df5fde8f3e04d24ffe480b47da28f4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a2df5fde8f3e04d24ffe480b47da28f4 = L.map(
#                 &quot;map_a2df5fde8f3e04d24ffe480b47da28f4&quot;,
#                 {
#                     center: [40.45418375156666, -3.6931826246333332],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fe78dd5372993ac712842a461226f20f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fe78dd5372993ac712842a461226f20f.addTo(map_a2df5fde8f3e04d24ffe480b47da28f4);
#
#
#             var marker_3d9595d27e26684a92b519637b34312e = L.marker(
#                 [40.453594, -3.6928477],
#                 {}
#             ).addTo(map_a2df5fde8f3e04d24ffe480b47da28f4);
#
#
#         var popup_c085d89d91b4f5ada1bc1011037730eb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fc951e8c71ca82fcb803135a0581ee1d = $(`&lt;div id=&quot;html_fc951e8c71ca82fcb803135a0581ee1d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_c085d89d91b4f5ada1bc1011037730eb.setContent(html_fc951e8c71ca82fcb803135a0581ee1d);
#
#
#
#         marker_3d9595d27e26684a92b519637b34312e.bindPopup(popup_c085d89d91b4f5ada1bc1011037730eb)
#         ;
#
#
#
#
#             var marker_bce8c8f441e88d7610e797d343ab17fb = L.marker(
#                 [40.453632, -3.6927545],
#                 {}
#             ).addTo(map_a2df5fde8f3e04d24ffe480b47da28f4);
#
#
#         var popup_0567a492203527c286ac52b22d6832ca = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6e9e48e74077033bac774e91a7912648 = $(`&lt;div id=&quot;html_6e9e48e74077033bac774e91a7912648&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_0567a492203527c286ac52b22d6832ca.setContent(html_6e9e48e74077033bac774e91a7912648);
#
#
#
#         marker_bce8c8f441e88d7610e797d343ab17fb.bindPopup(popup_0567a492203527c286ac52b22d6832ca)
#         ;
#
#
#
#
#             var marker_5f574f4cf3f05130f89b25f2d58f5ef7 = L.marker(
#                 [40.4536286, -3.6925569],
#                 {}
#             ).addTo(map_a2df5fde8f3e04d24ffe480b47da28f4);
#
#
#         var popup_d3e12872b1351d68f303e5e932580a76 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9ec0e8e217dfb8e25eee353bf9648145 = $(`&lt;div id=&quot;html_9ec0e8e217dfb8e25eee353bf9648145&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_d3e12872b1351d68f303e5e932580a76.setContent(html_9ec0e8e217dfb8e25eee353bf9648145);
#
#
#
#         marker_5f574f4cf3f05130f89b25f2d58f5ef7.bindPopup(popup_d3e12872b1351d68f303e5e932580a76)
#         ;
#
#
#
#
#             var marker_23cc33a6a3d5041ea34dfa060053f9a1 = L.marker(
#                 [40.4542069, -3.6934769],
#                 {}
#             ).addTo(map_a2df5fde8f3e04d24ffe480b47da28f4);
#
#
#         var popup_7f282932ef43b47871fbbd82131e43e8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8c456a66a3e42044de5796d69441b406 = $(`&lt;div id=&quot;html_8c456a66a3e42044de5796d69441b406&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_7f282932ef43b47871fbbd82131e43e8.setContent(html_8c456a66a3e42044de5796d69441b406);
#
#
#
#         marker_23cc33a6a3d5041ea34dfa060053f9a1.bindPopup(popup_7f282932ef43b47871fbbd82131e43e8)
#         ;
#
#
#
#
#             var marker_16210183e01313800b622aa744f3f6f9 = L.marker(
#                 [40.4543919, -3.6927729],
#                 {}
#             ).addTo(map_a2df5fde8f3e04d24ffe480b47da28f4);
#
#
#         var popup_60b5dc55aa53e337c04292cfe4f2b010 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2dd14f97be9a2c4a799cb3312bb1a45d = $(`&lt;div id=&quot;html_2dd14f97be9a2c4a799cb3312bb1a45d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Point&lt;/div&gt;`)[0];
#                 popup_60b5dc55aa53e337c04292cfe4f2b010.setContent(html_2dd14f97be9a2c4a799cb3312bb1a45d);
#
#
#
#         marker_16210183e01313800b622aa744f3f6f9.bindPopup(popup_60b5dc55aa53e337c04292cfe4f2b010)
#         ;
#
#
#
#
#             var marker_b29d0c5f415468fdb02fb798900825ad = L.marker(
#                 [40.4543553, -3.6933621],
#                 {}
#             ).addTo(map_a2df5fde8f3e04d24ffe480b47da28f4);

# %%
search.df[:1].to_dict()
# Out:
# {'_id': {0: '66-1176540468'},
#  'title': {0: 'Piso en venta en Poeta Joan Maragall Cuatro Caminos - Azca'},
#  'is_active': {0: 0},
#  'action_id': {0: 3},
#  'action_name': {0: 'Unpublished w/o confirmed date'},
#  'usage_id': {0: 1},
#  'usage_name': {0: 'Residential'},
#  'comparison_type': {0: 0},
#  'operation_type_id': {0: 1},
#  'operation_type_name': {0: 'Venta'},
#  'last_price': {0: 825000.0},
#  'last_pm2': {0: 5093.0},
#  'address': {0: 'Poeta Joan Maragall, Cuatro Caminos - Azca'},
#  'location': {0: {'coordinates': [-3.6928477, 40.453594], 'type': 'Point'}},
#  'distance': {0: 20},
#  'similarity': {0: 2},
#  'property_type_id': {0: 4},
#  'property_type_name': {0: 'Apartment'},
#  'subtypology_name': {0: 'Colective housing'},
#  'subtypology_type_id': {0: 2},
#  'typology_type_id': {0: 1},
#  'typology_type_name': {0: 'Residencial'},
#  'construction_type_id': {0: 2},
#  'construction_type_name': {0: 'Segunda mano'},
#  'build_status_id': {0: 0},
#  'build_status_name': {0: 'Desconocido'},
#  'date_in': {0: {'$date': '2023-01-26T00:00:00Z'}},
#  'date_out': {0: {'$date': '2023-06-20T00:00:00Z'}},
#  'has_air_conditioner': {0: 1.0},
#  'has_common_areas': {0: 0.0},
#  'has_elevator': {0: 1},
#  'has_garage': {0: 0.0},
#  'has_garage_in_price': {0: 0.0},
#  'has_gym': {0: 0.0},
#  'has_pool': {0: 0.0},
#  'has_racket_court': {0: 0.0},
#  'has_security': {0: 1.0},
#  'has_storage': {0: 1.0},
#  'furnished': {0: 0.0},
#  'is_exterior': {0: 0},
#  'is_agency': {0: 1},
#  'is_bank': {0: 0},
#  'is_coop': {0: 0},
#  'is_duplicate': {0: 0},
#  'is_short_rent': {0: False},
#  'is_vpo': {0: 0},
#  'cat_area': {0: 4},
#  'cat_rooms': {0: 3},
#  'category_id': {0: 4},
#  'n_rooms': {0: 3},
#  'n_baths': {0: 2},
#  'area': {0: 162.0},
#  'has_terrace': {0: 0.0},
#  'construction_year': {0: nan},
#  'date_diff': {0: 21},
#  'floor': {0: 2.0},
#  'is_accurate_address': {0: 0},
#  'admin0': {0: 'Spain'},
#  'admin1': {0: 'Comunidad de Madrid'},
#  'admin2': {0: 'Madrid'},
#  'admin3': {0: 'Madrid'},
#  'admin4': {0: 'Tetuán'},
#  'admin5': {0: 'Cuatro Caminos'},
#  'admin6': {0: 'Sección 046'},
#  'id_admin0': {0: 1},
#  'id_admin1': {0: 14},
#  'id_admin2': {0: 48},
#  'id_admin3': {0: 4440},
#  'id_admin4': {0: 13966},
#  'id_admin5': {0: 26619},
#  'id_admin6': {0: 51989},
#  'postal_code': {0: '28020'},
#  'geohash7': {0: 'ezjq5uq'},
#  'first_price': {0: 849000.0},
#  'first_pm2': {0: 5240.74},
#  'last_price_pm2_with_correction': {0: 4552.78},
#  'last_price_with_correction': {0: 737550.0},
#  'contact_url': {0: 'https://www.fotocasa.es/es/inmobiliaria-remax-omega/comprar/inmuebles/espana/todas-las-zonas/l?clientId=9202762464413'},
#  'retail_listing': {0: 'Fotocasa'},
#  'vendor_asset_id': {0: '9202762464413'},
#  'vendor_type': {0: 2},
#  'url': {0: 'https://www.fotocasa.es/es/comprar/vivienda/madrid-capital/aire-acondicionado-calefaccion-parking-trastero-ascensor/176540468/d'},
#  'energy_cert_name': {0: 'G'},
#  'cadastral_match': {0: [{'activity': 'Vivienda',
#     'address': 'CALLE POETA JOAN MARAGALL 3, MADRID (MADRID)',
#     'area_total_con_elementos_comunes': 162.0,
#     'area_uso': 134.0,
#     'cadastral_bi': '1385804VK4718E0037XQ',
#     'door': 'C',
#     'flg_pool': True,
#     'flg_year': True,
#     'floor': 2,
#     'lat': 40.45377867780001,
#     'lon': -3.6927146665369386,
#     'score': 1.0,
#     'score_10': 7.0,
#     'staircase': '',
#     'year_built': 1970},
#    {'activity': 'Vivienda',
#     'address': 'CALLE POETA JOAN MARAGALL 3, MADRID (MADRID)',
#     'area_total_con_elementos_comunes': 174.0,
#     'area_uso': 142.0,
#     'cadastral_bi': '1385804VK4718E0035BX',
#     'door': 'A',
#     'flg_pool': True,
#     'flg_year': True,
#     'floor': 2,
#     'lat': 40.45377867780001,
#     'lon': -3.6927146665369386,
#     'score': 2.0,
#     'score_10': 7.0,
#     'staircase': '',
#     'year_built': 1970},
#    {'activity': 'Vivienda',
#     'address': 'CALLE POETA JOAN MARAGALL 3, MADRID (MADRID)',
#     'area_total_con_elementos_comunes': 176.0,
#     'area_uso': 143.0,
#     'cadastral_bi': '1385804VK4718E0036ZM',
#     'door': 'B',
#     'flg_pool': True,
#     'flg_year': True,
#     'floor': 2,
#     'lat': 40.45377867780001,
#     'lon': -3.6927146665369386,
#     'score': 3.0,
#     'score_10': 7.0,
#     'staircase': '',
#     'year_built': 1970}]},
#  'closing_match': {0: None},
#  'images_list': {0: [{'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_581376073_1684693083.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895979_1677284216.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895987_1677284152.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_581376100_1684693084.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895997_1677284098.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895933_1677284125.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_581376083_1684693084.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895998_1677284392.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895935_1677284004.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895989_1677284177.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895976_1677284252.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895934_1677284447.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895992_1677284372.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895994_1677284216.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895965_1677284372.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895959_1677284321.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895977_1677284394.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895985_1677284356.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_581376071_1684693085.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895991_1677284151.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895969_1677284001.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895978_1677284337.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895951_1677284478.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895932_1677284338.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895996_1677284306.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895986_1677284410.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895988_1677284031.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895937_1677284431.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895990_1677284150.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895947_1677284099.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895939_1677284515.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895973_1677284515.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895975_1677284173.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895981_1677284336.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895993_1677284305.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895953_1677284199.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895936_1677284106.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895943_1677284044.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895982_1677284302.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_581376087_1684693080.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895995_1677284251.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895955_1677284427.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895967_1677284072.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895957_1677284302.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895983_1677284267.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895971_1677284411.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895974_1677284287.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895963_1677283980.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895941_1677284478.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895940_1677284252.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895984_1677284102.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895949_1677284177.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895980_1677284121.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895938_1677284466.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895945_1677283979.jpg'},
#    {'label': '',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895962_1677284447.jpg'}]},
#  'asking_closing_corr': {0: -0.106},
#  'estimated_mortgage': {0: 2957.7},
#  'hist_prices': {0: [{'date': '2023-01-26',
#     'price': 849000,
#     'price_m2': 5240.740740741},
#    {'date': '2023-02-24', 'price': 825000, 'price_m2': 5092.59}]},
#  'risk_area': {0: 0},
#  'sfn': {0: 0.9952},
#  'spc': {0: -4.0658},
#  'time_on_market_rent': {0: 7.0},
#  'time_on_market_sale': {0: 6.0},
#  'unit': {0: 1},
#  'unit_with_correction': {0: 0.894},
#  'valuation_rent': {0: 2345.0},
#  'valuation_sale': {0: 743687.0},
#  'gross_yield_asking_price': {0: 3.41},
#  'gross_yield_estimated_price': {0: 3.78},
#  'price_gap': {0: -9.86},
#  'md_cycle_sale': {0: 'Rising'},
#  'md_liquidity_rent': {0: 'A'},
#  'md_liquidity_sale': {0: 'B+'},
#  'md_volatility_sale': {0: 'BB'},
#  'output_priceunit_max_rent': {0: 21.0},
#  'output_priceunit_max_sale': {0: 5696.0},
#  'output_priceunit_min_rent': {0: 12.0},
#  'output_priceunit_min_sale': {0: 2990.0},
#  'score': {0: 100.0},
#  'score_distance': {0: 100}}

# %%
from utils import show_images

show_images(search.df.loc[:3])
# Out:
# <style type="text/css">
# </style>
# <table id="T_e5fc1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e5fc1_level0_col0" class="col_heading level0 col0" >_id</th>
#       <th id="T_e5fc1_level0_col1" class="col_heading level0 col1" >title</th>
#       <th id="T_e5fc1_level0_col2" class="col_heading level0 col2" >url</th>
#       <th id="T_e5fc1_level0_col3" class="col_heading level0 col3" >img1</th>
#       <th id="T_e5fc1_level0_col4" class="col_heading level0 col4" >img2</th>
#       <th id="T_e5fc1_level0_col5" class="col_heading level0 col5" >img3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e5fc1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e5fc1_row0_col0" class="data row0 col0" >66-1176540468</td>
#       <td id="T_e5fc1_row0_col1" class="data row0 col1" >Piso en venta en Poeta Joan Maragall Cuatro Caminos - Azca</td>
#       <td id="T_e5fc1_row0_col2" class="data row0 col2" ><a target="_blank" href="https://www.fotocasa.es/es/comprar/vivienda/madrid-capital/aire-acondicionado-calefaccion-parking-trastero-ascensor/176540468/d">https://www.fotocasa . 76540468/d</a></td>
#       <td id="T_e5fc1_row0_col3" class="data row0 col3" ><img width="200px" src="https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_581376073_1684693083.jpg"></a></td>
#       <td id="T_e5fc1_row0_col4" class="data row0 col4" ><img width="200px" src="https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895979_1677284216.jpg"></a></td>
#       <td id="T_e5fc1_row0_col5" class="data row0 col5" ><img width="200px" src="https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1176540468/66-1176540468_553895987_1677284152.jpg"></a></td>
#     </tr>
#     <tr>
#       <th id="T_e5fc1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e5fc1_row1_col0" class="data row1 col0" >66-1181361150</td>
#       <td id="T_e5fc1_row1_col1" class="data row1 col1" >Piso en venta en Calle del Poeta Joan Maragall, 3, Cuatro Caminos - Azca</td>
#       <td id="T_e5fc1_row1_col2" class="data row1 col2" ><a target="_blank" href="https://www.fotocasa.es/es/comprar/vivienda/madrid-capital/aire-acondicionado-terraza-trastero-ascensor/181361150/d/">https://www.fotocasa . 1361150/d/</a></td>
#       <td id="T_e5fc1_row1_col3" class="data row1 col3" ><img width="200px" src="https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1181361150/66-1181361150_5ef822b0-4aba-4d53-81bc-fbb8574665e8.rule=original"></a></td>
#       <td id="T_e5fc1_row1_col4" class="data row1 col4" ><img width="200px" src="https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1181361150/66-1181361150_6991e4b2-fb1e-4bdf-8d8d-f7333dc69fa4.rule=original"></a></td>
#       <td id="T_e5fc1_row1_col5" class="data row1 col5" ><img width="200px" src="https://storage.googleapis.com/uda-images/datalake-images/portals/spain/fotocasa/1181361150/66-1181361150_c25c5ffd-d871-4058-8261-44362cb73cb4.rule=original"></a></td>
#     </tr>
#     <tr>
#       <th id="T_e5fc1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e5fc1_row2_col0" class="data row2 col0" >54-103568328</td>
#       <td id="T_e5fc1_row2_col1" class="data row2 col1" >Piso en venta en Cuatro Caminos</td>
#       <td id="T_e5fc1_row2_col2" class="data row2 col2" ><a target="_blank" href="https://www.idealista.com/inmueble/103568328/">https://www.idealist . 103568328/</a></td>
#       <td id="T_e5fc1_row2_col3" class="data row2 col3" ><img width="200px" src="https://storage.googleapis.com/uda-images/datalake-images/portals/spain/idealista/103568328/54-103568328_1193598060.jpg"></a></td>
#       <td id="T_e5fc1_row2_col4" class="data row2 col4" ><img width="200px" src="https://storage.googleapis.com/uda-images/datalake-images/portals/spain/idealista/103568328/54-103568328_1193598076.jpg"></a></td>
#       <td id="T_e5fc1_row2_col5" class="data row2 col5" ><img width="200px" src="https://storage.googleapis.com/uda-images/datalake-images/portals/spain/idealista/103568328/54-103568328_1193598083.jpg"></a></td>
#     </tr>
#     <tr>
#       <th id="T_e5fc1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e5fc1_row3_col0" class="data row3 col0" >54-103458638</td>
#       <td id="T_e5fc1_row3_col1" class="data row3 col1" >Piso en venta en calle de Pedro Teixeira</td>
#       <td id="T_e5fc1_row3_col2" class="data row3 col2" ><a target="_blank" href="https://www.idealista.com/inmueble/103458638/">https://www.idealist . 103458638/</a></td>
#       <td id="T_e5fc1_row3_col3" class="data row3 col3" ><img width="200px" src="https://storage.googleapis.com/uda-images/datalake-images/portals/spain/idealista/103458638/54-103458638_1190163050.jpg"></a></td>
#       <td id="T_e5fc1_row3_col4" class="data row3 col4" ><img width="200px" src="https://storage.googleapis.com/uda-images/datalake-images/portals/spain/idealista/103458638/54-103458638_1190163103.jpg"></a></td>
#       <td id="T_e5fc1_row3_col5" class="data row3 col5" ><img width="200px" src="https://storage.googleapis.com/uda-images/datalake-images/portals/spain/idealista/103458638/54-103458638_1190163052.jpg"></a></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Running more complex queries

# %%
params = {

    'address': 'Av de Brasil 3, Madrid',     
    'area': '100,200',
    'is_active': 1,
    'operation_type_id': 1,
    'distance': 1000,

    # in order to get a finer scoring and sort by similarity
    'target_area': 150,
    'target_floor': 3,
    'target_baths': 2,
    'target_rooms': 3,
    'target_property_type': 1, # penthouses
    'target_has_elevator': 1,
    'target_has_storage': 1,
    'target_is_exterior': 1,
    'target_has_terrace': 1,
    'target_build_status': 1,
    
    'sort_by': 'similarity',
    'ascending': 0,

}

search = Search().request(**params)

search.df[:3]
# Out:
# Total: 147 - Page: 1/5
#             _id                                              title  is_active  \
# 0  54-105013400  Ático en venta en calle de Marceliano Santa María          1
# 1  54-104894877              Ático en venta en calle de Orense, 29          1
# 2  54-104594182                   Ático en venta en Cuatro Caminos          1
#
#    action_id action_name  usage_id   usage_name  comparison_type  \
# 0          2         Old         1  Residential                1
# 1          2         Old         1  Residential                1
# 2          2         Old         1  Residential                1
#
#    operation_type_id operation_type_name  ...  score_build_status_id  \
# 0                  1               Venta  ...                    100
# 1                  1               Venta  ...                    100
# 2                  1               Venta  ...                    100
#
#    score_has_elevator score_has_storage score_has_terrace  \
# 0                 100               100               100
# 1                 100                 0               100
# 2                 100                 0               100
#
#    score_has_air_conditioner  score_has_garage  score_has_pool  \
# 0                       None              None            None
# 1                       None              None            None
# 2                       None              None            None
#
#   score_is_exterior score_property_type_id  score_distance
# 0               100                  100.0       88.947216
# 1               100                  100.0       97.597347
# 2               100                  100.0      100.000000
#
# [3 rows x 123 columns]

# %%
show_images(search.df[:3])
# Out:
# <style type="text/css">
# </style>
# <table id="T_9a429">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9a429_level0_col0" class="col_heading level0 col0" >_id</th>
#       <th id="T_9a429_level0_col1" class="col_heading level0 col1" >title</th>
#       <th id="T_9a429_level0_col2" class="col_heading level0 col2" >url</th>
#       <th id="T_9a429_level0_col3" class="col_heading level0 col3" >img1</th>
#       <th id="T_9a429_level0_col4" class="col_heading level0 col4" >img2</th>
#       <th id="T_9a429_level0_col5" class="col_heading level0 col5" >img3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a429_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9a429_row0_col0" class="data row0 col0" >54-105013400</td>
#       <td id="T_9a429_row0_col1" class="data row0 col1" >Ático en venta en calle de Marceliano Santa María</td>
#       <td id="T_9a429_row0_col2" class="data row0 col2" ><a target="_blank" href="https://www.idealista.com/inmueble/105013400/">https://www.idealist . 105013400/</a></td>
#       <td id="T_9a429_row0_col3" class="data row0 col3" ><img width="200px" src="https://storage.googleapis.com/uda-images/datalake-images/portals/spain/idealista/105013400/54-105013400_1239092230.jpg"></a></td>
#       <td id="T_9a429_row0_col4" class="data row0 col4" ><img width="200px" src="https://storage.googleapis.com/uda-images/datalake-images/portals/spain/idealista/105013400/54-105013400_1239092218.jpg"></a></td>
#       <td id="T_9a429_row0_col5" class="data row0 col5" ><img width="200px" src="https://storage.googleapis.com/uda-images/datalake-images/portals/spain/idealista/105013400/54-105013400_1239092220.jpg"></a></td>
#     </tr>
#     <tr>
#       <th id="T_9a429_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9a429_row1_col0" class="data row1 col0" >54-104894877</td>
#       <td id="T_9a429_row1_col1" class="data row1 col1" >Ático en venta en calle de Orense, 29</td>
#       <td id="T_9a429_row1_col2" class="data row1 col2" ><a target="_blank" href="https://www.idealista.com/inmueble/104894877/">https://www.idealist . 104894877/</a></td>
#       <td id="T_9a429_row1_col3" class="data row1 col3" ><img width="200px" src="https://storage.googleapis.com/uda-images/datalake-images/portals/spain/idealista/104894877/54-104894877_1235067333.jpg"></a></td>
#       <td id="T_9a429_row1_col4" class="data row1 col4" ><img width="200px" src="https://storage.googleapis.com/uda-images/datalake-images/portals/spain/idealista/104894877/54-104894877_1235067312.jpg"></a></td>
#       <td id="T_9a429_row1_col5" class="data row1 col5" ><img width="200px" src="https://storage.googleapis.com/uda-images/datalake-images/portals/spain/idealista/104894877/54-104894877_1235067321.jpg"></a></td>
#     </tr>
#     <tr>
#       <th id="T_9a429_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9a429_row2_col0" class="data row2 col0" >54-104594182</td>
#       <td id="T_9a429_row2_col1" class="data row2 col1" >Ático en venta en Cuatro Caminos</td>
#       <td id="T_9a429_row2_col2" class="data row2 col2" ><a target="_blank" href="https://www.idealista.com/inmueble/104594182/">https://www.idealist . 104594182/</a></td>
#       <td id="T_9a429_row2_col3" class="data row2 col3" ><img width="200px" src="https://storage.googleapis.com/uda-images/datalake-images/portals/spain/idealista/104594182/54-104594182_1225505628.jpg"></a></td>
#       <td id="T_9a429_row2_col4" class="data row2 col4" ><img width="200px" src="https://storage.googleapis.com/uda-images/datalake-images/portals/spain/idealista/104594182/54-104594182_1225505615.jpg"></a></td>
#       <td id="T_9a429_row2_col5" class="data row2 col5" ><img width="200px" src="https://storage.googleapis.com/uda-images/datalake-images/portals/spain/idealista/104594182/54-104594182_1225505429.jpg"></a></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Checking on similarity scores

# %%
search.df.describe().score
# Out:
# count    30.000000
# mean     79.149766
# std       4.442971
# min      74.961977
# 25%      75.731935
# 50%      77.932430
# 75%      81.028217
# max      92.694178
# Name: score, dtype: float64

# %% [markdown]
# ## Checking on uDA's Valuation (AVM)

# %%
search.df.valuation_sale.describe().round()
# Out:
# count         30.0
# mean      762802.0
# std       191231.0
# min       464188.0
# 25%       623410.0
# 50%       760730.0
# 75%       877775.0
# max      1413220.0
# Name: valuation_sale, dtype: float64

# %% [markdown]
# ## Checking on other interesting indicators

# %%
search = Search().request(
    address="Villaverde, Madrid", 
    price='0,100000',
    area='50,150',
    operation_type_id=1, # sale
    gross_yield_asking_price = '5,12',
    target_area=100,
    is_active=1, # published
    sort_by='gross_yield_asking_price', 
    ascending=0,
    distance=1000,
)

maindrivers_zone = [c for c in search.df.columns if 'md_' in c]

others = ['_id', 'title', 'admin3', 'admin4', 'admin5', 'url', 'last_price_with_correction', 'valuation_sale', 'time_on_market_sale','time_on_market_rent', 'price_gap', 'gross_yield_asking_price']

search.df[others]
# Out:
# Total: 8 - Page: 1/1
#             _id                                              title  admin3  \
# 0  54-105064118                    Piso en venta en calle Calamina  Madrid
# 1  54-102609410                   Piso en venta en Villaverde Alto  Madrid
# 2  54-104644077                    Piso en venta en paseo Talleres  Madrid
# 3  54-104885544  Piso en venta en calle de Albino Hernández Lázaro  Madrid
# 4  54-102978094                       Piso en venta en Los Ángeles  Madrid
# 5  54-104876517                   Piso en venta en Villaverde Alto  Madrid
# 6  54-101263159              Dúplex en venta en calle de la Fuente  Madrid
# 7  54-101263161              Dúplex en venta en calle de la Fuente  Madrid
#
#        admin4      admin5                                            url  \
# 0  Villaverde  San Andrés  https://www.idealista.com/inmueble/105064118/
# 1  Villaverde  San Andrés  https://www.idealista.com/inmueble/102609410/
# 2  Villaverde  San Andrés  https://www.idealista.com/inmueble/104644077/
# 3  Villaverde  San Andrés  https://www.idealista.com/inmueble/104885544/
# 4  Villaverde  San Andrés  https://www.idealista.com/inmueble/102978094/
# 5  Villaverde  San Andrés  https://www.idealista.com/inmueble/104876517/
# 6  Villaverde  San Andrés  https://www.idealista.com/inmueble/101263159/
# 7  Villaverde  San Andrés  https://www.idealista.com/inmueble/101263161/
#
#    last_price_with_correction  valuation_sale  time_on_market_sale  \
# 0                    77710.08       125524.78                  8.0
# 1                    73382.40       111473.33                  8.0
# 2                    80192.00       136588.42                  8.0
# 3                    77056.00       118283.88                  9.0
# 4                    76070.40        98018.89                  9.0
# 5                    80640.00        94552.85                  9.0
# 6                    85120.00       102475.43                  9.0
# 7                    86912.00       102475.43                  9.0
#
#    time_on_market_rent  price_gap  gross_yield_asking_price
# 0                  5.0      44.73                     11.52
# 1                  5.0      36.11                     11.18
# 2                  5.0      52.61                     11.01
# 3                  3.0      37.54                     10.57
# 4                  3.0      15.45                     10.25
# 5                  3.0       5.06                      7.79
# 6                  3.0       7.87                      7.77
# 7                  3.0       5.64                      7.61

# %% [markdown]
# ## Checking on cadastral matchs

# %%
search = Search().request(
    address="Calle de Huesca 27, Madrid", 
    operation_type_id=1, # sale
    is_active=1, # published
    sort_by='similarity', 
    ascending=0
)

def read_match(x):
    print(f'\n{x._id} - {x.title} {x.url}')
    if match:=x.cadastral_match:
        match = sorted(match, key = lambda x: -x['score'])
        for c in match[:3]:
            print('\t', c.get('address'), c.get('floor'), c.get('cadastral_bi'), c.get('area_total_con_elementos_comunes'), c.get('score_10'))
        print('\t...')
        return
    print('\t...')
        
_ = search.df[:5].apply(lambda x: read_match(x), axis=1)
# Out:
# Total: 118 - Page: 1/4
#
# 54-104965509 - Piso en venta en calle de Huesca, 19 https://www.idealista.com/inmueble/104965509/
# 	 CALLE HUESCA 19, MADRID (MADRID) 2 0890408VK4709B0008WD 85.0 7.0
# 	 CALLE HUESCA 19, MADRID (MADRID) 2 0890408VK4709B0009EF 79.0 7.0
# 	 CALLE HUESCA 19, MADRID (MADRID) 2 0890408VK4709B0007QS 71.0 7.0
# 	...
#
# 54-104869914 - Piso en venta en Cuzco-Castillejos https://www.idealista.com/inmueble/104869914/
# 	 CALLE ROBLE 1, MADRID (MADRID) 6 0994803VK4709D0029MM 146.0 0.0
# 	 CALLE SAN GERMAN 57, MADRID (MADRID) 6 0789101VK4708H0214MD 157.0 0.0
# 	 CALLE ROBLE 3, MADRID (MADRID) 6 0994803VK4709D0060LL 150.0 0.0
# 	...
#
# 66-1182650959 - Piso en venta en Calle Hermano Gárate, Castillejos - Cuzco https://www.fotocasa.es/es/comprar/vivienda/madrid-capital/calefaccion-ascensor/182650959/d
# 	...
#
# 54-104072229 - Piso en venta en calle de San Germán https://www.idealista.com/inmueble/104072229/
# 	 CALLE SAN GERMAN 37, MADRID (MADRID) 2 0888210VK4708H0026WH 109.0 4.0
# 	 CALLE SAN GERMAN 37, MADRID (MADRID) 2 0888210VK4708H0014HU 115.0 4.0
# 	 CALLE SAN GERMAN 37, MADRID (MADRID) 2 0888210VK4708H0004OM 216.0 4.0
# 	...
#
# 54-104839744 - Piso en venta en calle del General Margallo https://www.idealista.com/inmueble/104839744/
# 	 CALLE GENERAL MARGALLO 4, MADRID (MADRID) 2 0993502VK4709D0010RU 76.0 5.0
# 	 CALLE GENERAL MARGALLO 4, MADRID (MADRID) 2 0993502VK4709D0015OS 77.0 5.0
# 	 CALLE GENERAL MARGALLO 4, MADRID (MADRID) 2 0993502VK4709D0011TI 89.0 5.0
# 	...

# %% [markdown]
# ## Checking on closings matchs

# %%
search = Search().request(
    address="calle huescsa 27, Madrid", 
    operation_type_id=1, # sale
    is_active=0, # published
    target_area=100,
    sort_by='score', 
    ascending=0
)

def read_match(x):
    print(f'\n{x._id} - {x.title} {x.score}')
    if match:=x.closing_match:
        match = sorted(match, key = lambda x: -x['score'])
        for c in match[:3]:
            print('\t', 'id:', c.get('clo_id_uda'), 'score:', c.get('score'))
        print('\t...')
        return
    print('\t...')
        
_ = search.df[:10].apply(lambda x: read_match(x), axis=1)
# Out:
# Total: 250 - Page: 1/9
#
# 66-1178501558 - Piso en venta en Castillejos - Cuzco 100.0
# 	...
#
# 54-103078289 - Piso en venta en calle de la Infanta Mercedes, 34 100.0
# 	 id: 41-5cfc122de6a582b7c22de712570c6c88_1 score: 5
# 	 id: 41-d0b63cceaf50d7644ea32e6ee1d63f95_1 score: 5
# 	 id: 41-6b9fc394b993ef676789e664536e3851_1 score: 5
# 	...
#
# 54-102935025 - Piso en venta en calle Hermano Gárate 100.0
# 	...
#
# 54-100804924 - Piso en venta en calle Hermano Gárate, 1 100.0
# 	 id: 41-711fe67fa356eabd2abbda81f622e25d_1 score: 0
# 	 id: 41-9719b5e72597353a7b76e007675e32cc_1 score: 0
# 	 id: 41-4b88862b53c6a236c2a27abca2260b53_1 score: 0
# 	...
#
# 54-101584916 - Dúplex en venta en Alonso Castrillo, 19 100.0
# 	 id: 41-c26b6334135ac16f497c05860868219f_1 score: 0
# 	 id: 41-aa2d1d559b49d62c73d8adb2617938a5_1 score: 0
# 	 id: 41-0267ac6c82dd86428654aec714862a56_1 score: 0
# 	...
#
# 54-102492870 - Piso en venta en calle de la Infanta Mercedes 100.0
# 	...
#
# 66-1165345109 - Piso en venta en Calle del Marqués de Leis 16 Castillejos - Cuzco 100.0
# 	...
#
# 73-35928756268_109800 - Garaje en venta en Calle de Lérida, 91, cerca de Calle de Huesca 100.0
# 	...
#
# 54-102021029 - Piso en venta en Cuzco-Castillejos 100.0
# 	...
#
# 66-1178521944 - Piso en venta en Calle de Lérida, 91, Castillejos - Cuzco 100.0
# 	...

# %% [markdown]
# ## Getting details on a single or multiple records

# %%
search = Search().request(
    id_uda="54-103078289,41-5cfc122de6a582b7c22de712570c6c88_1"
)

search.df.T.dropna().to_dict()
# Out:
# Total: 2 - Page: 1/1
# {0: {'_id': '41-5cfc122de6a582b7c22de712570c6c88_1',
#   'is_active': 0,
#   'usage_id': 1,
#   'usage_name': 'Residential',
#   'comparison_type': 2,
#   'operation_type_id': 1,
#   'operation_type_name': 'Venta',
#   'last_price': 253000.0,
#   'last_pm2': 2842.7,
#   'address': 'INFANTA MERCEDES, 34',
#   'location': {'coordinates': [-3.6976080847, 40.4571369517], 'type': 'Point'},
#   'similarity': 2,
#   'property_type_id': 4,
#   'property_type_name': 'Piso',
#   'typology_type_id': 1,
#   'typology_type_name': 'Residencial',
#   'construction_type_id': 2,
#   'construction_type_name': 'Segunda mano',
#   'build_status_id': 1,
#   'build_status_name': 'Good condition',
#   'has_elevator': 1,
#   'is_duplicate': 0,
#   'is_vpo': 0,
#   'cat_area': 2,
#   'category_id': 2,
#   'area': 89.0,
#   'is_accurate_address': 1,
#   'admin0': 'Spain',
#   'admin1': 'Comunidad de Madrid',
#   'admin2': 'Madrid',
#   'admin3': 'Madrid',
#   'admin4': 'Tetuán',
#   'admin5': 'Castillejos',
#   'admin6': 'Sección 060',
#   'id_admin0': 1,
#   'id_admin1': 14,
#   'id_admin2': 48,
#   'id_admin3': 4440,
#   'id_admin4': 13966,
#   'id_admin5': 26620,
#   'id_admin6': 52001,
#   'postal_code': '28020',
#   'geohash7': 'ezjq5ug',
#   'first_price': 253000.0,
#   'first_pm2': 2842.7,
#   'last_price_pm2_with_correction': 2842.7,
#   'last_price_with_correction': 253000.0,
#   'images_list': [{'label': 'catastro',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/es/catastro/0989905VK4708H.jpeg'}],
#   'hist_prices': [{'date': '2017-06-01', 'price': 253000, 'price_m2': 253000}],
#   'score': 100.0,
#   'score_distance': 100},
#  1: {'_id': '54-103078289',
#   'is_active': 0,
#   'usage_id': 1,
#   'usage_name': 'Residential',
#   'comparison_type': 0,
#   'operation_type_id': 1,
#   'operation_type_name': 'Venta',
#   'last_price': 449900.0,
#   'last_pm2': 4454.46,
#   'address': 'Calle de la Infanta Mercedes, 34',
#   'location': {'coordinates': [-3.6972286, 40.4585933], 'type': 'Point'},
#   'similarity': 2,
#   'property_type_id': 4,
#   'property_type_name': 'Apartment',
#   'typology_type_id': 1,
#   'typology_type_name': 'Residencial',
#   'construction_type_id': 2,
#   'construction_type_name': 'Segunda mano',
#   'build_status_id': 1,
#   'build_status_name': 'Buen estado',
#   'has_elevator': 1,
#   'is_duplicate': 0,
#   'is_vpo': 0,
#   'cat_area': 3,
#   'category_id': 3,
#   'area': 101.0,
#   'is_accurate_address': 1,
#   'admin0': 'Spain',
#   'admin1': 'Comunidad de Madrid',
#   'admin2': 'Madrid',
#   'admin3': 'Madrid',
#   'admin4': 'Tetuán',
#   'admin5': 'Castillejos',
#   'admin6': 'Sección 057',
#   'id_admin0': 1,
#   'id_admin1': 14,
#   'id_admin2': 48,
#   'id_admin3': 4440,
#   'id_admin4': 13966,
#   'id_admin5': 26620,
#   'id_admin6': 51998,
#   'postal_code': '28020',
#   'geohash7': 'ezjq5v7',
#   'first_price': 449900.0,
#   'first_pm2': 4454.46,
#   'last_price_pm2_with_correction': 4044.65,
#   'last_price_with_correction': 408509.2,
#   'images_list': [{'label': 'salon',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/idealista/103078289/54-103078289_1177499250.jpg'},
#    {'label': 'cocina',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/idealista/103078289/54-103078289_1177577866.jpg'},
#    {'label': 'dormitorio',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/idealista/103078289/54-103078289_1177500082.jpg'},
#    {'label': 'dormitorio',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/idealista/103078289/54-103078289_1178158024.jpg'},
#    {'label': 'dormitorio',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/idealista/103078289/54-103078289_1177577067.jpg'},
#    {'label': 'dormitorio',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/idealista/103078289/54-103078289_1177576799.jpg'},
#    {'label': 'bano',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/idealista/103078289/54-103078289_1177577046.jpg'},
#    {'label': 'bano',
#     'url': 'https://storage.googleapis.com/uda-images/datalake-images/portals/spain/idealista/103078289/54-103078289_1177576956.jpg'}],
#   'hist_prices': [{'date': '2023-11-09',
#     'price': 449900,
#     'price_m2': 4454.455445545}],
#   'score': 100.0,
#   'score_distance': 100}}
